# %%
# Bug: Mutable default argument
def add_item(item, items=None):
    if items is None:
        items = []
    items.append(item)
    return items
print(add_item(1))
print(add_item(2))
# Out:
# [1]
# [2]

# %%
#Bug: Floating point precision issue
def check_sum():
    return abs((0.1 + 0.2) - 0.3) < 1e-9
print(check_sum())
# Out:
# True

# %%
# Bug: No base case
def countdown(n):
    print(n)
    if n > 0:
        countdown(n-1)
countdown(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
# Bug: Accessing non-existing key
def get_value():
    data = {"a": 1, "b": 2}
    return data.get("c", "Key not found")
print(get_value())
# Out:
# Key not found

# %%
# Bug: Infinite loop
def loop_example():
    i = 0
    while i < 5:
        print(i)
        # Missing increment of i, causing an infinite loop
        i += 1
loop_example()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Bug: Wrong unpacking
def unpack_example():
    a, b = [1, 2, 3][:2] #fix Bug: Too many values to unpack
    return a, b
print(unpack_example())
# Out:
# (1, 2)

# %%
# Bug: Mixed indentation
def func():
    x = 5
    y = 10
    return x+y
print(func())
# Out:
# 15

# %%
# Bug: Wrong import
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
# Bug: Early return inside loop
def total(numbers):
    total = 0
    for n in numbers:
        total += n
    return total
print(total([1,2,3]))
# Out:
# 6

# %%
# Bug: Using undefined variable

def calculate_area(length, width):
    return length * width
assert calculate_area(5, 3) == 15
assert calculate_area(10, 2) == 20
assert calculate_area(7, 4) == 28
print("All assertions passed!")
# Out:
# All assertions passed!

# %%
# Bug: Adding integer and string
def add_values():
    return 5 + int("10")
print(add_values())
#Verify with 3 assert cases
assert add_values() == 15
assert add_values() == 15
assert add_values() == 15
print("All assertions passed!")
# Out:
# 15
# All assertions passed!

# %%
# Bug: Adding string and list
def combine():
    return "Numbers: " + str([1, 2, 3])   
print(combine())
assert combine() == "Numbers: [1, 2, 3]"
assert combine() == "Numbers: [1, 2, 3]"
assert combine() == "Numbers: [1, 2, 3]"
print("All assertions passed!")
# Out:
# Numbers: [1, 2, 3]
# All assertions passed!

# %%
# Bug: Multiplying string by float
def repeat_text():
    return "Hello " * int(3.5)
print(repeat_text())
assert repeat_text() == "Hello Hello Hello "
assert repeat_text() == "Hello Hello Hello "
assert repeat_text() == "Hello Hello Hello "
print("All assertions passed!")
# Out:
# Hello Hello Hello
# All assertions passed!

# %%
# Bug: Adding None and integer
def compute():
 value = None
 return value or 0 + 10

print(compute())
# Out:
# 10

# %%
# Bug: Input remains string
def sum_two_numbers(num1, num2):
    a = int(num1)
    b = int(num2)
    return a + b
print(sum_two_numbers("5", "10"))
# Out:
# 15
