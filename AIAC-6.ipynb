# %%
class Student:
    def __init__(self, name: str, roll_no: str, branch: str):
        self.name = name
        self.roll_no = roll_no
        self.branch = branch

    def display_details(self):
        print("Student Details:")
        print(f"Name       : {self.name}")
        print(f"Roll Number: {self.roll_no}")
        print(f"Branch     : {self.branch}")


# take input and execute
name = input("Enter student's name: ").strip()
roll_no = input("Enter roll number: ").strip()
branch = input("Enter branch: ").strip()

student = Student(name, roll_no, branch)
student.display_details()
# Out:
# Student Details:
# Name       : sharini
# Roll Number: 4011
# Branch     : cse

# %%
#generate a function that prints the first 10 multiples of a given number by taking user input
def print_multiples():
    num = int(input("Enter a number: "))
    print(f"The first 10 multiples of {num} are:")
    for i in range(1, 11):
        print(num * i)
print_multiples() 

#generate the same functionality using another controlled looping structure (e.g.,while instead of for)
def print_multiples_while():
    num = int(input("Enter a number: "))
    print(f"The first 10 multiples of {num} are:")
    count = 1
    while count <= 10:
        print(num * count)
        count += 1   
print_multiples_while()
# Out:
# The first 10 multiples of 5 are:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50
# The first 10 multiples of 4 are:
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40

# %%
# generate nested if-elif-else conditional statements to classify age groups(e.g., child, teenager, adult, senior)
def classify_age():
    age = int(input("Enter your age: "))
    if age < 13:
        print("You are classified as a Child.")
    elif 13 <= age < 20:
        print("You are classified as a Teenager.")
    elif 20 <= age < 60:
        print("You are classified as an Adult.")
    else:
        print("You are classified as a Senior.")
classify_age()

# Analyze the generated conditions and logic, generate the same classification using alternative conditional structures (e.g.,simplified conditions or dictionary-based logic)
def classify_age_alternative():
    age = int(input("Enter your age: "))
    age_groups = {
        "Child": lambda x: x < 13,
        "Teenager": lambda x: 13 <= x < 20,
        "Adult": lambda x: 20 <= x < 60,
        "Senior": lambda x: x >= 60
    }
    for group, condition in age_groups.items():
        if condition(age):
            print(f"You are classified as a {group}.")
            break
classify_age_alternative()
# Out:
# You are classified as an Adult.
# You are classified as a Child.

# %%
#generate a sum_to_n() function using a for loop.
def sum_to_n_for():
    n = int(input("Enter a positive integer n: "))
    total = 0
    for i in range(1, n + 1):
        total += i
    print(f"The sum of the first {n} natural numbers is: {total}")

#Analyze the generated code.suggest an alternative implementation using a while loop or a mathematical formula
def sum_to_n_while():
    n = int(input("Enter a positive integer n: "))
    total = 0
    i = 1
    while i <= n:
        total += i
        i += 1
    print(f"The sum of the first {n} natural numbers is: {total}")

def sum_to_n_formula(n):
    return n * (n + 1) // 2
sum_to_n_for()
sum_to_n_while()
def sum_to_n_formula_wrapper():
    n = int(input("Enter a positive integer n: "))
    total = sum_to_n_formula(n)
    print(f"The sum of the first {n} natural numbers is: {total}")
# Out:
# The sum of the first 6 natural numbers is: 21
# The sum of the first 4 natural numbers is: 10

# %%
#generate a Bank Account class with methods such as deposit(), withdraw(),and check_balance()
class BankAccount:
    def __init__(self, account_number, initial_balance=0):
        self.account_number = account_number
        self.balance = initial_balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited ${amount}. New balance: ${self.balance}")
        else:  
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self.balance}")
        else:
            print("Invalid withdrawal amount or insufficient funds.")

    def check_balance(self):
        print(f"Account {self.account_number} has a balance of ${self.balance}")

# Example usage:
account = BankAccount("12345", 100)
account.check_balance()
account.deposit(50)
account.withdraw(30)
account.check_balance()

#Analyze the AI-generated class structure and logic.Add meaningful comments and explain the working of the code
# The BankAccount class is designed to simulate a basic bank account with essential functionalities.
# The __init__ method initializes the account with an account number and an initial balance (default is 0).
# The deposit method adds funds to the account, ensuring the amount is positive.
# The withdraw method removes funds from the account, ensuring the amount is positive and does not exceed the current balance.
# The check_balance method displays the current balance of the account.
# Out:
# Account 12345 has a balance of $100
# Deposited $50. New balance: $150
# Withdrew $30. New balance: $120
# Account 12345 has a balance of $120
